# %%
import numpy
import scipy
import matplotlib.pyplot as plt
import sympy

# %% [markdown]
# ### Definimos los símbolos

# %%
k = sympy.symbols('k', integer=True)
z = sympy.symbols('z')

# %% [markdown]
# ### Definimos la función

# %%
def f(k):
    # return (1/3)**k
    # return 1

# %% [markdown]
# ### Calculamos la transformada Z de la función f

# %%
unitstep = sympy.Sum(((1/3)**k)*z**(-k), (k, 0, sympy.oo))
unitstep
# Out:
# Sum(0.333333333333333**k/z**k, (k, 0, oo))

# %%
sform = unitstep.doit()
sform
# Out:
# Sum(0.333333333333333**k/z**k, (k, 0, oo))

# %%
uz = sform.args[0][0]
uz
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 uz = sform.args[0][0]
#       2 uz
#
# TypeError: 'Mul' object is not subscriptable
